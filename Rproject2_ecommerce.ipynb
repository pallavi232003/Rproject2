# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavi232003/Rproject2/blob/main/Rproject2_ecommerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()

'''from google.colab import drive
drive.mount('/content/drive')'''
# Out:
#      <input type="file" id="files-b2d97255-14b7-4137-86d4-2a1ebc080be2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2d97255-14b7-4137-86d4-2a1ebc080be2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("ecommerce_sales_data_realistic.csv")
'''df = pd.read_csv('/content/drive/My Drive/folder/your_file.csv')'''
df.head()
# Out:
#                                Order_ID                           Customer_ID  \
# 0  89134fe4-8655-4830-a447-b2909f45a323  88849a20-4051-4d66-901c-c951c0f27b20
# 1                                   NaN  0b1e3c62-3fe2-420f-9c62-8e5e51d1a34c
# 2  6c65c163-01ab-46ff-917f-95a5b6d75147  5bcdc529-1c1d-44a5-a3da-c1bea08ba795
# 3  3ee23373-a4cb-47cb-8aed-8c4d8f373a51  89e503dd-e5c3-4fc8-a9f7-c5a5b9c21dae
# 4  b466f4ef-59f9-4dfb-8e8a-66cd0d7bdac0  0e9b67eb-8999-4dd3-8257-6c4a611161f1
#
#                              Product_ID        Category Sub_Category  \
# 0  a333df76-8511-4e17-acbb-458249740ee7        Clothing        Shoes
# 1  1c8a048b-8e01-4458-a7e9-a358209f54ee  Home & Kitchen        Decor
# 2  8405b1ec-6d51-4c90-bf0f-67afee9ca517           Books       Comics
# 3  a5c211b4-c038-40af-8989-b0c4330ce22e  Home & Kitchen   Appliances
# 4  fdd68240-1def-4136-8568-839c9005b0f3        Clothing        Shoes
#
#   Purchase_Date  Quantity  Unit_Price  Total_Price                  City  \
# ...

# %%
df.tail()
# Out:
#                                     Order_ID  \
# 100995  cdfeffa6-3611-4095-98b9-da98425244d8
# 100996  15072388-3bf6-4699-aa76-eba24c7dd06e
# 100997  afa296e5-04aa-4e6d-9435-37984986a9a0
# 100998  4102c9be-5331-4faf-811b-edc3974231a3
# 100999  b811825f-2d5a-47c3-8a35-e96190d78150
#
#                                  Customer_ID  \
# 100995  5c402d13-35c7-4116-8142-ac0bb9e1824f
# 100996  c6ee76fb-adb7-463b-bfe5-8eb4fb5af5aa
# 100997  d2cb98c5-3d4b-42bb-bb3f-9e084e289586
# 100998  163586ac-4042-45ae-885c-23061682f578
# 100999  be0e6395-8b7d-444c-a9ae-755cf886a8ab
#
#                                   Product_ID     Category Sub_Category  \
# 100995  1ab20d7b-37ec-466e-a4f9-9c7cacabd459  Electronics   Headphones
# 100996  0dfb48d0-84b6-402e-b76b-14699cd3510b  Electronics       Tablet
# 100997                                   NaN         Toys   Board Game
# 100998                                   NaN     Clothing      T-Shirt
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101000 entries, 0 to 100999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        96039 non-null  object
#  1   Customer_ID     95997 non-null  object
#  2   Product_ID      96197 non-null  object
#  3   Category        96149 non-null  object
#  4   Sub_Category    96068 non-null  object
#  5   Purchase_Date   96147 non-null  object
#  6   Quantity        96050 non-null  float64
#  7   Unit_Price      96007 non-null  float64
#  8   Total_Price     96101 non-null  float64
#  9   City            95950 non-null  object
#  10  Country         95993 non-null  object
#  11  Payment_Method  96058 non-null  object
#  12  Discount        96168 non-null  float64
#  13  Profit_Margin   96032 non-null  float64
#  14  Order_Status    96046 non-null  object
# dtypes: float64(5), object(10)
# memory usage: 11.6+ MB

# %%
df.describe()
# Out:
#            Quantity    Unit_Price   Total_Price      Discount  Profit_Margin
# count  96050.000000  96007.000000  96101.000000  96168.000000   96032.000000
# mean       3.001114    252.414305    643.493628      0.149847     112.510965
# std        1.413458    142.757254    510.700784      0.086811     107.355685
# min        1.000000      5.000000      3.870000      0.000000       0.250000
# 25%        2.000000    129.185000    237.130000      0.070000      33.970000
# 50%        3.000000    252.310000    500.450000      0.150000      77.510000
# 75%        4.000000    375.855000    947.880000      0.230000     158.012500
# max        5.000000    500.000000   2498.900000      0.300000     729.200000

# %%
df.shape
# Out:
# (101000, 15)

# %%
df.size
# Out:
# 1515000

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Product_ID', 'Category', 'Sub_Category',
#        'Purchase_Date', 'Quantity', 'Unit_Price', 'Total_Price', 'City',
#        'Country', 'Payment_Method', 'Discount', 'Profit_Margin',
#        'Order_Status'],
#       dtype='object')

# %%
df.columns.value_counts()
# Out:
# Order_ID          1
# Customer_ID       1
# Product_ID        1
# Category          1
# Sub_Category      1
# Purchase_Date     1
# Quantity          1
# Unit_Price        1
# Total_Price       1
# City              1
# Country           1
# Payment_Method    1
# Discount          1
# Profit_Margin     1
# Order_Status      1
# Name: count, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Order_ID', 'Customer_ID', 'Product_ID', 'Category', 'Sub_Category',
#        'Purchase_Date', 'Quantity', 'Unit_Price', 'Total_Price', 'City',
#        'Country', 'Payment_Method', 'Discount', 'Profit_Margin',
#        'Order_Status'],
#       dtype='object')

# %%
column =df.columns
print(column)
# Out:
# Index(['Order_ID', 'Customer_ID', 'Product_ID', 'Category', 'Sub_Category',
#        'Purchase_Date', 'Quantity', 'Unit_Price', 'Total_Price', 'City',
#        'Country', 'Payment_Method', 'Discount', 'Profit_Margin',
#        'Order_Status'],
#       dtype='object')

# %%
cat_cols = df.select_dtypes(include=['object' , 'category']).columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
print("Categorical Columns:",list(cat_cols))
print("Numerical Columns:", list(num_cols))
# Out:
# Categorical Columns: ['Order_ID', 'Customer_ID', 'Product_ID', 'Category', 'Sub_Category', 'Purchase_Date', 'City', 'Country', 'Payment_Method', 'Order_Status']
# Numerical Columns: ['Quantity', 'Unit_Price', 'Total_Price', 'Discount', 'Profit_Margin']

# %%
df.duplicated().sum()
# Out:
# np.int64(1000)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop(columns=['Product_ID'],axis=1)

# %%
df.isnull().sum()
# Out:
# Order_ID          4908
# Customer_ID       4959
# Product_ID        4748
# Category          4783
# Sub_Category      4885
# Purchase_Date     4815
# Quantity          4893
# Unit_Price        4939
# Total_Price       4838
# City              5000
# Country           4961
# Payment_Method    4895
# Discount          4789
# Profit_Margin     4916
# Order_Status      4900
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# Order_ID          4.908
# Customer_ID       4.959
# Product_ID        4.748
# Category          4.783
# Sub_Category      4.885
# Purchase_Date     4.815
# Quantity          4.893
# Unit_Price        4.939
# Total_Price       4.838
# City              5.000
# Country           4.961
# Payment_Method    4.895
# Discount          4.789
# Profit_Margin     4.916
# Order_Status      4.900
# dtype: float64

# %%
sns.histplot(df['Profit_Margin'], kde=True)
plt.show()
sns.boxplot(x=df['Profit_Margin'])
plt.show()

# %%
# as the hisoplot shows, the graph is completely right skewed we need to use median
df['Profit_Margin'].fillna(df['Profit_Margin'].median(), inplace=True)

# %%
sns.histplot(df['Profit_Margin'], kde=True)
plt.show()

# %%
'''df['Profit_Margin'].fillna(df['Profit_Margin'].median(), inplace=True)'''

# %%
df.isnull().sum()
# Out:
# Order_ID          4908
# Customer_ID       4959
# Product_ID        4748
# Category          4783
# Sub_Category      4885
# Purchase_Date     4815
# Quantity          4893
# Unit_Price        4939
# Total_Price       4838
# City              5000
# Country           4961
# Payment_Method    4895
# Discount          4789
# Profit_Margin        0
# Order_Status      4900
# dtype: int64

# %%
sns.histplot(df['Payment_Method'], kde=True)
# Out:
# <Axes: xlabel='Payment_Method', ylabel='Count'>

# %%
sns.histplot(df['Discount'], kde=True)
# Out:
# <Axes: xlabel='Discount', ylabel='Count'>

# %%
min_price = df['Discount'].min()
max_price = df['Discount'].max()

print(f"Minimum Discount: {min_price}")
print(f"Maximum Discount: {max_price}")
# Out:
# Minimum Discount: 0.0
# Maximum Discount: 0.3

# %%
# 2️ Min & Max
min_val = df['Discount'].min()
max_val = df['Discount'].max()

# 3️ Percentiles (25th, 50th (median), 75th)
q25 = df['Discount'].quantile(0.25)
median = df['Discount'].median()
q75 = df['Discount'].quantile(0.75)

# 4️ Standard Deviation (for spread)
std_dev = df['Discount'].std()

# 5️ Print results
print(f"Minimum: {min_val}")
print(f"Maximum: {max_val}")
print(f"25th Percentile: {q25}")
print(f"Median (50th Percentile): {median}")
print(f"75th Percentile: {q75}")
print(f"Standard Deviation: {std_dev}")

# 6️ (Optional) Visual: Histogram

sns.histplot(df['Discount'], kde=False, bins=20)
plt.title('Discount Distribution')
plt.xlabel('Discount')
plt.ylabel('Frequency')
plt.show()
# Out:
# Minimum: 0.0
# Maximum: 0.3
# 25th Percentile: 0.07
# Median (50th Percentile): 0.15
# 75th Percentile: 0.23
# Standard Deviation: 0.08681479856870088

# %%
df['Discount'].fillna(df['Discount'].mean(), inplace=True)

# %%
sns.histplot(df['Discount'], kde=True)
# Out:
# <Axes: xlabel='Discount', ylabel='Count'>

# %%
sns.boxplot(x=df['Discount'])
plt.show()

# %%
df.isnull().sum()
# Out:
# Order_ID          4908
# Customer_ID       4959
# Product_ID        4748
# Category          4783
# Sub_Category      4885
# Purchase_Date     4815
# Quantity          4893
# Unit_Price        4939
# Total_Price       4838
# City              5000
# Country           4961
# Payment_Method    4895
# Discount             0
# Profit_Margin        0
# Order_Status      4900
# dtype: int64

# %%
numerical_cols = ['Quantity', 'Unit_Price']
categorical_cols = ['Category', 'Sub_Category', 'Payment_Method', 'Order_Status']

# Plot numerical columns: Histogram + KDE
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=20)
    plt.title(f'{col}: Histogram & KDE')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# categorical columns: Countplot
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=col, data=df)
    plt.title(f'{col}: Count Plot')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Filling categorical columns with mode
for col in ['Category', 'Sub_Category', 'Payment_Method', 'Order_Status']:
    mode_val = df[col].mode()[0]
    df[col].fillna(mode_val, inplace=True)

# Filling Purchase_Date with a placeholder
df['Purchase_Date'].fillna('Unknown', inplace=True)

# Fill Quantity with median
quantity_median = df['Quantity'].median()
df['Quantity'].fillna(quantity_median, inplace=True)

# Fill Unit_Price with random sampling
df['Unit_Price'] = df['Unit_Price'].apply(
    lambda x: x if pd.notnull(x) else df['Unit_Price'].dropna().sample(1).values[0]
)

# %%
df.isnull().sum()
# Out:
# Order_ID          4961
# Customer_ID       5003
# Category             0
# Sub_Category         0
# Purchase_Date        0
# Quantity             0
# Unit_Price           0
# Total_Price       4899
# City              5050
# Country           5007
# Payment_Method       0
# Discount             0
# Profit_Margin        0
# Order_Status         0
# dtype: int64

# %%
df['New_Combined_ID'] = df.apply(
    lambda row: str(row['Order_ID']) if pd.isna(row['Customer_ID'])
    else row['Customer_ID'] + str(row['Order_ID']),
    axis=1
)

# %% [markdown]
# Here we are removing the columns "common_ID, Order_ID, Customer_ID" as we added New_Combined_ID	we dont require these columns

# %%
df.drop(['common_ID','Order_ID','Customer_ID'], axis=1, inplace=True)

# %%
# Move 'New_Combined_ID' to the first column
cols = ['New_Combined_ID'] + [col for col in df.columns if col != 'New_Combined_ID']
df = df[cols]

# %%
df.head()
# Out:
#                                      New_Combined_ID  \
# 0  88849a20-4051-4d66-901c-c951c0f27b2089134fe4-8...
# 1            0b1e3c62-3fe2-420f-9c62-8e5e51d1a34cnan
# 2  5bcdc529-1c1d-44a5-a3da-c1bea08ba7956c65c163-0...
# 3  89e503dd-e5c3-4fc8-a9f7-c5a5b9c21dae3ee23373-a...
# 4  0e9b67eb-8999-4dd3-8257-6c4a611161f1b466f4ef-5...
#
#                              Product_ID        Category Sub_Category  \
# 0  a333df76-8511-4e17-acbb-458249740ee7        Clothing        Shoes
# 1  1c8a048b-8e01-4458-a7e9-a358209f54ee  Home & Kitchen        Decor
# 2  8405b1ec-6d51-4c90-bf0f-67afee9ca517           Books       Comics
# 3  a5c211b4-c038-40af-8989-b0c4330ce22e  Home & Kitchen   Appliances
# 4  fdd68240-1def-4136-8568-839c9005b0f3        Clothing        Shoes
#
#   Purchase_Date  Quantity  Unit_Price  Total_Price                  City  \
# 0    2023-06-12       3.0       60.45       150.52            Lawsonfurt
# 1    2024-03-16       2.0      425.94       792.25     East Williamburgh
# ...

# %% [markdown]
# # Summary Statistics

# %%
print(df[['Order_ID', 'Customer_ID']].describe())

print(df[['Quantity', 'Unit_Price']].describe())
# Out:
#                                     Order_ID  \
# count                                  96039
# unique                                 95092
# top     0169beab-6932-4d0f-b253-4af2bdfd97b2
# freq                                       2
#
#                                  Customer_ID
# count                                  95997
# unique                                 95041
# top     b31c4113-0726-4db5-82e3-1665b7141baf
# freq                                       2
#             Quantity     Unit_Price
# count  101000.000000  101000.000000
# mean        3.001059     252.471057
# std         1.378386     142.723082
# min         1.000000       5.000000
# 25%         2.000000     129.320000
# 50%         3.000000     252.400000
# 75%         4.000000     375.880000
# max         5.000000     500.000000

# %% [markdown]
# # Trend Analysis: Sales Over Time

# %%
# Convert Purchase_Date to datetime (if it's not already) in the analysing part else also by the dataset created person
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'], errors='coerce')

# Group by date: Total Sales & Total Quantity
daily_sales = df.groupby('Purchase_Date').agg({
    'Total_Price': 'sum',
    'Quantity': 'sum'
}).reset_index()


plt.figure(figsize=(10,5))
sns.lineplot(x='Purchase_Date', y='Total_Price', data=daily_sales)
plt.title('Daily Total Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()


plt.figure(figsize=(10,5))
sns.lineplot(x='Purchase_Date', y='Quantity', data=daily_sales)
plt.title('Daily Quantity Trend')
plt.xlabel('Date')
plt.ylabel('Total Quantity')
plt.show()

# %% [markdown]
# # Group By Analysis

# %%
category_sales = df.groupby('Category')['Total_Price'].sum().reset_index()

plt.figure(figsize=(8,5))
sns.barplot(x='Category', y='Total_Price', data=category_sales)
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# # Profit Margin by Payment Method:

# %%
payment_profit = df.groupby('Payment_Method')['Profit_Margin'].mean().reset_index()

plt.figure(figsize=(8,5))
sns.barplot(x='Payment_Method', y='Profit_Margin', data=payment_profit)
plt.title('Average Profit Margin by Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Average Profit Margin')
plt.show()

# %% [markdown]
# # Outliers Detection

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['Quantity'])
plt.title('Boxplot of Quantity')
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x=df['Unit_Price'])
plt.title('Boxplot of Unit Price')
plt.show()


plt.figure(figsize=(6,4))
sns.boxplot(x=df['Discount'])
plt.title('Boxplot of Discount')
plt.show()


'''plt.figure(figsize=(1,5))
sns.boxplot(x=df['Profit_Margin'])
plt.tiltle("Boxplot of profit_margin")
plt.show()'''

plt.figure (figsize=(6,4))
sns.boxplot(x=df['Profit_Margin'])
plt.title('Boxplot of Total_Price')
plt.show()

# %% [markdown]
# # Coorelation Check (heatmap)

# %%
'''sns.heatmap(x=df['Quantity'], y=df['Unit_Price'])
plt.title('Correlation Heatmap')
plt.show()'''

num_cols = ['Quantity', 'Unit_Price']

corr = df[num_cols].corr()

plt.figure(figsize=(6,5))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
'''# Calculate Q1 and Q3
Q1 = df['Profit_Margin'].quantile(0.25)
Q3 = df['Profit_Margin'].quantile(0.75)
IQR = Q3 - Q1
print(Q1)
print(Q3)
print(IQR)

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound)
print(upper_bound)

# Filter out outliers
df_no_outliers = df[(df['Profit_Margin'] < lower_bound) & (df['Profit_Margin'] > upper_bound)]

print(f"Original dataset size: {df.shape}")
print(f"Dataset size after removing outliers: {df_no_outliers.shape}")'''



# Calculate Q1, Q3, IQR
Q1 = df['Profit_Margin'].quantile(0.25)
Q3 = df['Profit_Margin'].quantile(0.75)
IQR = Q3 - Q1

print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR}")

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower bound: {lower_bound}")
print(f"Upper bound: {upper_bound}")

# Filter non-outliers
df_no_outliers = df[(df['Profit_Margin'] >= lower_bound) & (df['Profit_Margin'] <= upper_bound)]

# Calculate number of outliers
num_outliers = df.shape[0] - df_no_outliers.shape[0]

print(f"Original dataset size: {df.shape[0]}")
print(f"Dataset size after removing outliers: {df_no_outliers.shape[0]}")
print(f"Number of outliers in Profit_Margin: {num_outliers}")
# Out:
# Q1: 35.77
# Q3: 152.2225
# IQR: 116.45249999999999
# Lower bound: -138.90874999999997
# Upper bound: 326.90125
# Original dataset size: 100000
# Dataset size after removing outliers: 94641
# Number of outliers in Profit_Margin: 5359

# %%
sns.boxplot(x='Discount', data=df_no_outliers)
plt.title('Boxplot of Discount (Outliers Removed)')
plt.show()
